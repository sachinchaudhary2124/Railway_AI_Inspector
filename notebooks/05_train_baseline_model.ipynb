# %% [markdown]
# ## Railway AI Inspector - Baseline CNN Training
# ## Objective
# Train the first baseline Convolutional Neural Network (CNN)
# to classify railway track conditions into:
#
# - Normal
# - Crack
# - Broken Rail
# - Misalignment
# - Surface Wear
